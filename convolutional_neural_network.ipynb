# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.20.0'

# %%
import os
os.listdir("S37 - dataset")
# Out:
# ['dataset', '__MACOSX']

# %%
import os
os.listdir("S37 - dataset/dataset")
# Out:
# ['.DS_Store', 'test_set', 'training_set']

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen=ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)
training_set=train_datagen.flow_from_directory(
    'S37 - dataset/dataset/training_set',
    target_size=(64,64),
    batch_size=16,
    class_mode='binary'
)
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen=ImageDataGenerator(rescale=1./255)
test_set=test_datagen.flow_from_directory('S37 - dataset/dataset/test_set',
                                          target_size=(64,64),
                                          batch_size=16,
                                          class_mode='binary')
# Out:
# Found 2001 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn=tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64,64,3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x=training_set,validation_data=test_set,epochs=14)
# Out:
# Epoch 1/14
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 85s 169ms/step - accuracy: 0.6683 - loss: 0.6059 - val_accuracy: 0.7276 - val_loss: 0.5552
# Epoch 2/14
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - accuracy: 0.7160 - loss: 0.5632 - val_accuracy: 0.7501 - val_loss: 0.5144
# Epoch 3/14
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 43s 85ms/step - accuracy: 0.7293 - loss: 0.5283 - val_accuracy: 0.7591 - val_loss: 0.5032
# Epoch 4/14
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 49s 98ms/step - accuracy: 0.7519 - loss: 0.5015 - val_accuracy: 0.7616 - val_loss: 0.5231
# Epoch 5/14
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 45s 90ms/step - accuracy: 0.7706 - loss: 0.4819 - val_accuracy: 0.7526 - val_loss: 0.5218
# Epoch 6/14
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 44s 88ms/step - accuracy: 0.7824 - loss: 0.4633 - val_accuracy: 0.7776 - val_loss: 0.4776
# Epoch 7/14
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 57s 113ms/step - accuracy: 0.7884 - loss: 0.4437 - val_accuracy: 0.7776 - val_loss: 0.4789
# Epoch 8/14
# ...

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import os
os.path.exists("S37 - dataset/dataset/single_prediction")
# Out:
# False

# %%
import os
os.listdir("S37 - dataset/dataset/test_set")
# Out:
# ['.DS_Store', 'cats', 'dogs']

# %%
os.listdir("S37 - dataset/dataset/test_set/cats")[:5]
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'cat.4001.jpg',
#  'cat.4002.jpg',
#  'cat.4003.jpg']

# %%
import shutil

src = "S37 - dataset/dataset/test_set/cats/cat.4001.jpg"
dst = "S37 - dataset/dataset/single_prediction/cat.4001.jpg"

shutil.copy(src, dst)
# Out:
# 'S37 - dataset/dataset/single_prediction/cat.4001.jpg'

# %%
import numpy as np
from keras.preprocessing import image
test_image=image.load_img('S37 - dataset/dataset/single_prediction/dog.4689.jpg',target_size=(64,64))
test_image=image.img_to_array(test_image)
test_image=np.expand_dims(test_image,axis=0)
result=cnn.predict(test_image)
training_set.class_indices
if result[0][0]==1:
   prediction='dog'
else:
   prediction='cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step

# %%
print(prediction)
# Out:
# cat
